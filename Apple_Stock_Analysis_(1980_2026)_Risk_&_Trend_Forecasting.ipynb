# %% [markdown]
# <a href="https://colab.research.google.com/github/windythalia/analysis-telco/blob/main/Apple_Stock_Analysis_(1980_2026)_Risk_%26_Trend_Forecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import and Reading Data**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 90)

# %%
df = pd.read_csv('aapl_master_enriched.csv')

# %% [markdown]
# # **Data Understanding**
# *   Dataframe shape
# *   head and tail
# *   dtypes
# *   describe

# %%
df.shape
# Out:
# (11370, 81)

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-964094849.py in <cell line: 0>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'dividends',
#        'stock_splits', 'price_range', 'price_change', 'price_change_pct',
#        'sma_5', 'ema_5', 'sma_10', 'ema_10', 'sma_20', 'ema_20', 'sma_50',
#        'ema_50', 'sma_100', 'ema_100', 'sma_200', 'ema_200', 'volatility_5d',
#        'volatility_10d', 'volatility_20d', 'volatility_50d', 'rsi_14', 'macd',
#        'macd_signal', 'macd_histogram', 'bb_middle', 'bb_upper', 'bb_lower',
#        'bb_width', 'volume_sma_20', 'volume_ratio', 'return_1d', 'return_5d',
#        'return_10d', 'return_20d', 'return_60d', 'return_120d', 'return_252d',
#        'close_lag_1', 'volume_lag_1', 'close_lag_2', 'volume_lag_2',
#        'close_lag_3', 'volume_lag_3', 'close_lag_5', 'volume_lag_5',
#        'close_lag_10', 'volume_lag_10', 'target_return_1d', 'target_direction',
#        'year', 'month', 'day', 'dayofweek', 'quarter', 'is_month_start',
# ...

# %%
df.dtypes
# Out:
# date                        object
# open                       float64
# high                       float64
# low                        float64
# close                      float64
# volume                       int64
# dividends                  float64
# stock_splits               float64
# price_range                float64
# price_change               float64
# price_change_pct           float64
# sma_5                      float64
# ema_5                      float64
# sma_10                     float64
# ema_10                     float64
# sma_20                     float64
# ema_20                     float64
# sma_50                     float64
# ema_50                     float64
# sma_100                    float64
# ema_100                    float64
# sma_200                    float64
# ema_200                    float64
# volatility_5d              float64
# volatility_10d             float64
# volatility_20d             float64
# volatility_50d             float64
# ...

# %%
df.describe()
# Out:
#                open          high           low         close        volume  \
# count  11370.000000  11370.000000  11370.000000  11370.000000  1.137000e+04
# mean      28.247180     28.551948     27.959821     28.268216  3.093870e+08
# std       58.332434     58.953390     57.758590     58.382179  3.333205e+08
# min        0.038072      0.038072      0.037645      0.037645  0.000000e+00
# 25%        0.246489      0.252683      0.240865      0.245779  1.060811e+08
# 50%        0.485038      0.493956      0.474584      0.484580  1.986064e+08
# 75%       21.603634     21.842335     21.377591     21.629225  3.896942e+08
# max      286.200012    288.619995    283.299988    286.190002  7.421641e+09
#
#           dividends  stock_splits   price_range  price_change  \
# count  11370.000000  11370.000000  11370.000000  11370.000000
# mean       0.000862      0.001495      0.592128      0.021036
# std        0.012952      0.082283      1.411644      0.924420
# ...

# %% [markdown]
# # **Data Preparation**
#
# *   Dropping irrelevant columns and rows
# *   Identifying duplicated columns
# *   Renaming columns
# *   Feature creation
